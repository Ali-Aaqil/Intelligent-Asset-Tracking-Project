# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")  # YOLOv11 model variant

results = model.predict(
    source="test_data.mp4",  # Your input video
    save=True,                   # Save annotated output
    conf=0.3,                    # Confidence threshold
    show=False                   # Turn to True if you want window popups (not needed in Jupyter)
)
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 6.97MB/s]
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/647) C:\Users\JK\R&D\test_data.mp4: 384x640 2 trucks, 671.1ms
# video 1/1 (frame 2/647) C:\Users\JK\R&D\test_data.mp4: 384x640 2 trucks, 585.0ms
# video 1/1 (frame 3/647) C:\Users\JK\R&D\test_data.mp4: 384x640 2 trucks, 581.4ms
# ...
